# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Import the pandas library
import pandas as pd

#Load the Excel file from Google Drive
file_path = '/content/gdrive/My Drive/before icc rawww.xlsx'
df = pd.read_excel(file_path) # Use pd to access the read_excel function

# %%
# Preview
df.head()
# Out:
#        List  Rater-A  Rater-D  Rater-P
# 0  app-1,Q1        4        4        3
# 1  app-1,Q2        4        4        4
# 2  app-1,Q3        3        3        3
# 3  app-1,Q4        3        5        3
# 4  app-1,Q5        4        3        4

# %%
# !pip install pingouin openpyxl

# %%
import pingouin as pg

# Calculate ICC
icc_results = pg.intraclass_corr(data=long_df, targets='Row_ID', raters='Rater', ratings='Score')

# Set index to 'Description' for easy access
icc_results = icc_results.set_index('Description')

# Extract the ICC2 (Single random raters)
icc = icc_results.loc['Single random raters', 'ICC']
ci_lower, ci_upper = icc_results.loc['Single random raters', 'CI95%']

print(f"ICC = {icc:.3f}, 95% CI = [{ci_lower}, {ci_upper}]")
# Out:
# ICC = 0.905, 95% CI = [0.89, 0.92]
